# %%
print("merhabalar,IGU SEM Otonom Sistemler 20.01.26")
# Out:
# merhabalar,IGU SEM Otonom Sistemler 20.01.26

# %%
import sys #import python programlama dilinde kütüphane eklemeye yarayan bir kod blogudur.
print (sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Ders_no=4 #İnteger veri türü
pi_sayısı=3.14159 # float veri türü
Dersin_ismi="pyhton - veri yapıları" # string veri türü
durum1= True
durum2= False

print(Ders_no)
print(pi_sayısı)
print(Dersin_ismi)
print(durum1)
print(durum2)
# Out:
# 4
# 3.14159
# pyhton - veri yapıları
# True
# False

# %%
a=7
b=3
print(a+b)
# Out:
# 10

# %%
a=7
b=3
print("Çarpma:", a*b)
print("Üs alma:", a**b)
print("Mod alma", a%b)
# Out:
# Çarpma: 21
# Üs alma: 343
# Mod alma 1

# %%
a==7
b==3
print("a==b:", a==b)
print("a<b:", a>b)
# Out:
# a==b: False
# a<b: True

# %%
a=True
b=False
print("a and b:", a and b)
print("a or b:", a or b)
print("not a", not a)
# Out:
# a and b: False
# a or b: True
# not a False

# %%
x=7
x+=3 # x = x+3
print(x)
# Out:
# 10

# %%
a=7
b=3
print("a& b:", a&b)
print("a<< b:", a<<b)
# Out:
# a& b: 3
# a<< b: 56

# %%
a=7
b=3
print(7&3) #and
print(7|3) #or
print(7^3) #not
print(~3)
print(7<<3)
print(7>>3)
# Out:
# 3
# 7
# 4
# -4
# 56
# 0
