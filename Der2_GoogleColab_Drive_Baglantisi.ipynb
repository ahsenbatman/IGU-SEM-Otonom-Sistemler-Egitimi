# %% [markdown]
# IGU SEM EGİTİMİ
#
# bu kod blogu üzerinde google drive ile colab platformlarının eşleşmesi sağlanmaktadır. Eşleşme anında drive alanınızda aşağıdaki kod içerisinde olan "IGUSEM_OTONOM" dosyası olmak zorundadır.
#
# Ahsen Batman
# Ocak 2026

# %%
print("merhabalar,IGU SEM Otonom Sistemler 20.01.26")
# Out:
# merhabalar,IGU SEM Otonom Sistemler 20.01.26

# %%
import sys #import python programlama dilinde kütüphane eklemeye yarayan bir kod blogudur.
print (sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/IGUSEM_OTONOM')
# !pwd # ilk kod blogunun cıktısını bize veren bir kod blogudur.
# Out:
# /content/drive/My Drive/IGUSEM_OTONOM
